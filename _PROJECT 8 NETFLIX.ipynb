# %% [raw]
# NETFLIX
#
# This NETFLIX dataset has information about the TV shows and Movies available on Netflix till 2021.
#
# this dataset is collected from flixable which is a third-party netflix search engine,and available on kaggle website

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix=pd.read_csv(r"C:\Users\admin\Downloads\Netflix_Dataset.csv")

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix

# %%
netflix.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [raw]
# Task.1.is there any Duplicate Record in this dataset? if yes,then remove the duplicate records.

# %%
netflix[netflix.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
netflix.drop_duplicates() #remove the duplicate records
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.shape
# Out:
# (7789, 11)

# %%
netflix.drop_duplicates(inplace = True) #to remove rows permanently

# %%
netflix.shape
# Out:
# (7787, 11)

# %% [raw]
# Task.2.is there any Null Value present in any column ? show with heat-map.

# %%
netflix.isnull() #to show where is null value is present
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
netflix.isnull().sum() #to show count of null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(netflix.isnull())
plt.show()

# %% [raw]
# Q.1. For 'House of Cards',what is the Show id and Who is the Director of this show ?

# %%
netflix.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
netflix["Title"].unique()
# Out:
# array(['3%', '07:19', '23:59', ..., 'Zulu Man in Japan',
#        "Zumbo's Just Desserts", "ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS"],
#       dtype=object)

# %%
netflix[netflix["Title"].isin(["House of Cards"])] #to show all records of  particular item in any column
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [raw]
# STR.CONTAINS()

# %%
netflix[netflix["Title"].str.contains("House of Cards")] #to show all records of a particular string in any column
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [raw]
# Q.2.in which year highest number of the TV Show & Movies were released? Show with Bar Graph

# %%
netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
netflix.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
netflix["Date_n"] = pd.to_datetime(netflix["Release_Date"].str.strip())

# %%
netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_n
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_n          datetime64[ns]
# dtype: object

# %%
netflix["year"] = netflix["Date_n"].dt.year

# %%
netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_n    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
netflix["year"].value_counts()
# Out:
# year
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
netflix["year"].value_counts().plot(kind = "bar")
plt.title("yearwise highest number of the TV Show & Movies were released")
plt.xlabel("year")
plt.ylabel("numbers")
plt.show();

# %% [raw]
# Q.3.how many Movies & TV Show are in the dataset ? show with Bar Graph.

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
netflix.groupby("Category").Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
netflix.groupby("Category").Category.count().plot(kind = "bar",color = ["green","red"])
plt.title("Movies & TV Show")
plt.xlabel("Category")
plt.ylabel("numbers");

# %%
#sns.countplot(netflix=Category,colour =["red","green"])
#sns.countplot(data=netflix, x='Category', palette=['red', 'green'])
#sns.countplot(data=netflix, x='Category', palette='Set2')
sns.countplot(data=netflix, x='Category',hue='Category', palette='Set1')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count by Category')
plt.show()

# %% [raw]
# Q.4.Show all the Movies that were released in year 2020.

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_n          datetime64[ns]
# year                   float64
# dtype: object

# %%
netflix["year"] = netflix["year"].fillna(0).astype(int)

# %%
netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_n          datetime64[ns]
# year                     int32
# dtype: object

# %%
netflix[(netflix["Category"]== "Movie") & (netflix["year"] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [raw]
# Q.5.Show only the Titles of all TV Show that were released in india only.

# %%
netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_n  year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016

# %%
netflix[(netflix["Category"] == "TV Show") & (netflix["Country"] == "India")]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [raw]
# Q.6.Show Top 10 Directors,who gave the highest number of TV Shows & Movies to Netflix?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020

# %%
netflix["Director"].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: count, dtype: int64

# %% [raw]
# Q.7.Show all the Records, where "Category is Movie and Type is Comedies" or "country is United Kingdom".

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020

# %%
netflix[((netflix["Category"] == "Movie") & (netflix["Type"]=="Comedies")) | (netflix["Country"] == "United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [raw]
# Q.8.in how many movies/shows, Tom Cruise was cast?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020

# %%
netflix[netflix["Cast"].isin(["Tom Cruise"])]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_n, year]
# Index: []

# %%
netflix[netflix["Cast"].str.contains("Tom Cruise")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 netflix[netflix["Cast"].str.contains("Tom Cruise")]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
# -> 4092 if com.is_bool_indexer(key):
#    4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %%
#creating a new dataframe 
netflix1 = netflix.dropna()  #it drops the rows that contains all or any missing values.

# %%
netflix1.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_n  year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
netflix1[netflix1["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_n  year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [raw]
# Q.9.What are the different Ratings defined by Netflix?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020

# %%
netflix["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix["Rating"].nunique()
# Out:
# 14

# %% [raw]
# Q.9.1.How many Movies got the 'TV-14' rating, in Canada?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020

# %%
netflix[(netflix["Category"] == "Movie") & (netflix["Rating"] == "TV-14") & (netflix["Country"] == "Canada")]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
netflix[(netflix["Category"] == "Movie") & (netflix["Rating"] == "TV-14") & (netflix["Country"] == "Canada")].shape
# Out:
# (11, 13)

# %% [raw]
# Q.9.2.How many TV Show got the 'R' rating, after year 2018?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020

# %%
netflix[(netflix["Category"] == "TV Show") & (netflix["Rating"] == "R") & (netflix["year"] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_n  year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019

# %% [raw]
# Q.10.What is the maximum duration of a movies/show on Netflix?

# %%
netflix.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_n          datetime64[ns]
# year                     int32
# dtype: object

# %%
netflix["Duration"].nunique()
# Out:
# 216

# %% [raw]
# str.split()

# %%
netflix[["minutes","unit"]] = netflix["Duration"].str.split(' ',expand = True)

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020       4
#
#       unit
# 0  Seasons

# %%
netflix[["minutes","Category"]].max()
# Out:
# minutes          99
# Category    TV Show
# dtype: object

# %% [raw]
# Q.11.which individual country has the Highest No.of TV shows?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020       4
#
#       unit
# 0  Seasons

# %%
netflix[netflix["Category"] == "TV Show"]["Country"].value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
netflix[(netflix["Category"] == "TV Show") & (netflix["Country"] == "United States")]
# Out:
#      Show_Id Category                               Title            Director  \
# 26       s27  TV Show                            (Un)Well                 NaN
# 29       s30  TV Show                            #blackAF                 NaN
# 53       s54  TV Show                          100 Humans                 NaN
# 63       s64  TV Show                      13 Reasons Why                 NaN
# 64       s65  TV Show  13 Reasons Why: Beyond the Reasons                 NaN
# ...      ...      ...                                 ...                 ...
# 7714   s7713  TV Show                        Yo-Kai Watch                 NaN
# 7723   s7722  TV Show                                 You  Lee Toland Krieger
# 7732   s7731  TV Show                        You vs. Wild                 NaN
# 7737   s7736  TV Show                      Young & Hungry                 NaN
# 7757   s7756  TV Show                            Z Nation                 NaN
#
# ...

# %% [raw]
# Q.12.How can we sort the dataset by year?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020       4
#
#       unit
# 0  Seasons

# %%
netflix.sort_values(by = "year",ascending = True)
# Out:
#      Show_Id Category                            Title              Director  \
# 3946   s3947  TV Show                            Maron                   NaN
# 549     s550  TV Show  Anthony Bourdain: Parts Unknown                   NaN
# 6066   s6066  TV Show     The Adventures of Figaro Pho                   NaN
# 2555   s2556  TV Show                  Gunslinger Girl                   NaN
# 3492   s3493  TV Show              La Familia P. Luche                   NaN
# ...      ...      ...                              ...                   ...
# 692     s693    Movie                   Bad Grandpa .5         Jeff Tremaine
# 2413   s2414    Movie                    Gimme Shelter            Ron Krauss
# 5521   s5521    Movie               Sex and the City 2  Michael Patrick King
# 7553   s7552    Movie        What Happened to Mr. Cha?          Kim Dong-kyu
# 3062   s3063    Movie              Is Love Enough? Sir           Rohena Gera
#
# ...

# %%
netflix.sort_values(by = "year",ascending = False).head(10)
# Out:
#      Show_Id Category                          Title  \
# 7353   s7352    Movie                        Unknown
# 3521   s3522    Movie                         Lagaan
# 5521   s5521    Movie             Sex and the City 2
# 2349   s2350    Movie                      Gangaajal
# 2672   s2673  TV Show  Headspace Guide to Meditation
# 104     s105    Movie             30 Minutes or Less
# 5139   s5139    Movie                     Redemption
# 2013   s2014    Movie               Enter the Dragon
# 6502   s6501    Movie               The Intouchables
# 1194   s1195    Movie              Can't Hardly Wait
#
#                             Director  \
# 7353              Jaume Collet-Serra
# 3521              Ashutosh Gowariker
# 5521            Michael Patrick King
# 2349                     Prakash Jha
# 2672                             NaN
# 104                  Ruben Fleischer
# 5139                   Steven Knight
# 2013                   Robert Clouse
# ...

# %% [raw]
# Q.13.find all instances where :
# Category is 'movie' and type is 'Dramas'
# or
# Category is 'TV show' & type is 'kids'TV'

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_n  year minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020       4
#
#       unit
# 0  Seasons

# %%
netflix[(netflix["Category"] == "Movie") & (netflix["Type"] == "Dramas")]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [raw]
# Category is 'TV show' & type is 'kids'TV'

# %%
netflix[(netflix["Category"] == "TV Show") & (netflix["Type"] == "Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
netflix[(netflix["Category"] == "Movie") & (netflix["Type"] == "Dramas") | (netflix["Category"] == "TV Show") & (netflix["Type"] == "Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
